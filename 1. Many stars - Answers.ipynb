# %% [markdown]
# ## The Problem
#
# - Have a sample of F-type stars (stars.csv)
# - FeI/FeII EWs have been measured (lines.csv)
# - Need to determine spectroscopic parameters
# - Have to use the Sun as reference

# %%
import q2

# %% [markdown]
# Load csv data into a **q2.Data** object.

# %%
d = q2.Data('stars.csv', 'lines.csv')

# %% [markdown]
# Use **q2.specpars.solve_all** to calculate spectroscopic parameters for all stars relative to the Sun.

# %%
sp = q2.specpars.SolvePars()
q2.specpars.solve_all(d, sp, 'solution.csv', reference_star='Sun')
# Out:
# ------------------------------------------------------
# Initializing ...
# - Date and time: 01-Aug-2017, 20:11:59
# - Model atmospheres: odfnew
# - Star data: stars.csv
# - Line list: lines.csv
# ------------------------------------------------------
#
# ***
# Sun
# ***
# Reference star. No calculations needed.
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 5777 4.44  0.000 1.00 --->  0.000+/-0.000
# --
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.000  0.000 ||  0.000  0.000   0 |  0.000  0.000   0
# ------------------------------------------------------
#
# ******
# hd4813
# ******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 ---> -0.181+/-0.103
#  1 6032 3.98 -0.181 1.32 ---> -0.231+/-0.060
#  2 6064 4.30 -0.231 1.64 ---> -0.252+/-0.066
#  3 6096 3.98 -0.252 1.32 ---> -0.194+/-0.059
#  4 6128 4.30 -0.194 1.64 ---> -0.213+/-0.053
#  5 6160 3.98 -0.213 1.32 ---> -0.156+/-0.064
#  6 6192 4.30 -0.156 1.64 ---> -0.176+/-0.046
#  7 6224 4.62 -0.176 1.32 ---> -0.108+/-0.049
#  8 6256 4.30 -0.108 1.00 ---> -0.044+/-0.061
#  9 6224 4.62 -0.044 1.32 ---> -0.099+/-0.053
# 10 6256 4.30 -0.099 1.00 ---> -0.043+/-0.061
# -- Converged at iteration 10 of 50
# 11 6240 4.46 -0.043 1.16 ---> -0.067+/-0.042
# 12 6224 4.30 -0.067 1.32 ---> -0.109+/-0.036
# 13 6240 4.46 -0.109 1.48 ---> -0.119+/-0.035
# 14 6256 4.30 -0.119 1.32 ---> -0.097+/-0.039
# 15 6272 4.46 -0.097 1.48 ---> -0.102+/-0.034
# 16 6256 4.62 -0.102 1.32 ---> -0.085+/-0.044
# 17 6240 4.46 -0.085 1.16 ---> -0.070+/-0.042
# -- Converged at iteration 17 of 50
# 18 6232 4.38 -0.070 1.24 ---> -0.089+/-0.037
# 19 6240 4.30 -0.089 1.32 ---> -0.102+/-0.037
# 20 6248 4.38 -0.102 1.40 ---> -0.107+/-0.033
# 21 6256 4.46 -0.107 1.32 ---> -0.089+/-0.032
# 22 6248 4.38 -0.089 1.40 ---> -0.107+/-0.033
# 23 6256 4.46 -0.107 1.32 ---> -0.089+/-0.032
# -- Converged at iteration 23 of 50
# 24 6252 4.42 -0.089 1.36 ---> -0.099+/-0.032
# 25 6256 4.38 -0.099 1.40 ---> -0.105+/-0.033
# 26 6260 4.42 -0.105 1.36 ---> -0.095+/-0.032
# 27 6256 4.46 -0.095 1.40 ---> -0.100+/-0.032
# -- Converged at iteration 27 of 50
# 28 6258 4.44 -0.100 1.38 ---> -0.097+/-0.032
# 29 6256 4.46 -0.097 1.36 ---> -0.094+/-0.032
# 30 6254 4.44 -0.094 1.34 ---> -0.094+/-0.032
# 31 6252 4.42 -0.094 1.36 ---> -0.099+/-0.032
# 32 6254 4.44 -0.099 1.38 ---> -0.100+/-0.032
# 33 6256 4.42 -0.100 1.36 ---> -0.097+/-0.032
# -- Converged at iteration 33 of 50
# -- Begin final loop
# 34 6255 4.43 -0.097 1.37 ---> -0.098+/-0.032
# 35 6256 4.44 -0.098 1.36 ---> -0.096+/-0.032
# 36 6255 4.43 -0.096 1.37 ---> -0.098+/-0.032
# -- Converged at iteration 36 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
# -0.098  0.032 || -0.098  0.032  86 | -0.099  0.030  17
# ------------------------------------------------------
#
# ******
# hd9826
# ******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 --->  0.074+/-0.158
#  1 6032 3.98  0.074 1.32 --->  0.028+/-0.113
#  2 6064 3.66  0.028 1.64 ---> -0.041+/-0.112
#  3 6096 3.98 -0.041 1.96 ---> -0.069+/-0.112
#  4 6128 4.30 -0.069 1.64 --->  0.016+/-0.101
#  5 6160 3.98  0.016 1.32 --->  0.102+/-0.103
#  6 6192 4.30  0.102 1.64 --->  0.056+/-0.094
#  7 6224 3.98  0.056 1.32 --->  0.135+/-0.105
#  8 6256 4.30  0.135 1.64 --->  0.089+/-0.088
#  9 6288 3.98  0.089 1.32 --->  0.166+/-0.111
# 10 6320 4.30  0.166 1.64 --->  0.128+/-0.087
# 11 6352 4.62  0.128 1.32 --->  0.215+/-0.099
# 12 6320 4.30  0.215 1.64 --->  0.129+/-0.087
# 13 6352 4.62  0.129 1.32 --->  0.215+/-0.099
# -- Converged at iteration 13 of 50
# 14 6336 4.46  0.215 1.48 --->  0.178+/-0.087
# 15 6320 4.30  0.178 1.64 --->  0.128+/-0.087
# 16 6336 4.46  0.128 1.48 --->  0.174+/-0.087
# -- Converged at iteration 16 of 50
# 17 6328 4.38  0.174 1.56 --->  0.152+/-0.086
# 18 6336 4.30  0.152 1.48 --->  0.168+/-0.088
# 19 6328 4.38  0.168 1.56 --->  0.151+/-0.086
# -- Converged at iteration 19 of 50
# 20 6332 4.34  0.151 1.52 --->  0.159+/-0.086
# 21 6328 4.38  0.159 1.56 --->  0.151+/-0.086
# 22 6332 4.42  0.151 1.52 --->  0.163+/-0.086
# 23 6328 4.38  0.163 1.48 --->  0.167+/-0.087
# -- Converged at iteration 23 of 50
# 24 6326 4.36  0.167 1.50 --->  0.161+/-0.086
# 25 6328 4.34  0.161 1.52 --->  0.157+/-0.086
# 26 6330 4.36  0.157 1.54 --->  0.155+/-0.086
# 27 6332 4.38  0.155 1.52 --->  0.161+/-0.086
# 28 6330 4.36  0.161 1.54 --->  0.155+/-0.086
# 29 6332 4.38  0.155 1.52 --->  0.161+/-0.086
# -- Converged at iteration 29 of 50
# -- Begin final loop
# 30 6331 4.37  0.161 1.53 --->  0.158+/-0.086
# 31 6330 4.38  0.158 1.54 --->  0.156+/-0.086
# 32 6329 4.37  0.156 1.53 --->  0.157+/-0.086
# 33 6330 4.38  0.157 1.54 --->  0.156+/-0.086
# 34 6329 4.37  0.156 1.53 --->  0.157+/-0.086
# -- Converged at iteration 34 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.157  0.086 ||  0.157  0.093  84 |  0.155  0.050  18
# ------------------------------------------------------
#
# *******
# hd16673
# *******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 ---> -0.116+/-0.124
#  1 6032 3.98 -0.116 1.32 ---> -0.168+/-0.079
#  2 6064 3.66 -0.168 1.64 ---> -0.225+/-0.101
#  3 6096 3.98 -0.225 1.32 ---> -0.133+/-0.073
#  4 6128 4.30 -0.133 1.64 ---> -0.157+/-0.069
#  5 6160 3.98 -0.157 1.32 ---> -0.094+/-0.073
#  6 6192 4.30 -0.094 1.64 ---> -0.120+/-0.058
#  7 6224 3.98 -0.120 1.32 ---> -0.059+/-0.078
#  8 6256 4.30 -0.059 1.64 ---> -0.088+/-0.055
#  9 6288 4.62 -0.088 1.32 ---> -0.008+/-0.054
# 10 6320 4.30 -0.008 1.64 ---> -0.048+/-0.058
# 11 6352 4.62 -0.048 1.32 --->  0.031+/-0.045
# 12 6320 4.30  0.031 1.64 ---> -0.045+/-0.057
# 13 6352 4.62 -0.045 1.32 --->  0.031+/-0.046
# -- Converged at iteration 13 of 50
# 14 6336 4.46  0.031 1.48 ---> -0.002+/-0.043
# 15 6352 4.62 -0.002 1.32 --->  0.034+/-0.046
# 16 6336 4.46  0.034 1.48 ---> -0.002+/-0.043
# -- Converged at iteration 16 of 50
# 17 6344 4.54 -0.002 1.40 --->  0.017+/-0.041
# 18 6336 4.46  0.017 1.48 ---> -0.002+/-0.043
# 19 6344 4.54 -0.002 1.40 --->  0.017+/-0.041
# -- Converged at iteration 19 of 50
# 20 6340 4.50  0.017 1.44 --->  0.009+/-0.041
# 21 6344 4.54  0.009 1.40 --->  0.018+/-0.041
# 22 6340 4.50  0.018 1.44 --->  0.009+/-0.041
# -- Converged at iteration 22 of 50
# 23 6342 4.52  0.009 1.42 --->  0.013+/-0.041
# 24 6340 4.50  0.013 1.40 --->  0.015+/-0.041
# 25 6338 4.52  0.015 1.42 --->  0.011+/-0.041
# 26 6336 4.50  0.011 1.40 --->  0.013+/-0.041
# 27 6334 4.52  0.013 1.42 --->  0.009+/-0.041
# 28 6336 4.50  0.009 1.40 --->  0.013+/-0.041
# 29 6334 4.52  0.013 1.42 --->  0.009+/-0.041
# -- Converged at iteration 29 of 50
# -- Begin final loop
# 30 6335 4.51  0.009 1.41 --->  0.011+/-0.041
# 31 6336 4.50  0.011 1.42 --->  0.010+/-0.041
# 32 6337 4.51  0.010 1.41 --->  0.012+/-0.041
# 33 6336 4.50  0.012 1.42 --->  0.010+/-0.041
# 34 6337 4.51  0.010 1.41 --->  0.012+/-0.041
# -- Converged at iteration 34 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.012  0.041 ||  0.012  0.039  86 |  0.014  0.053  18
# ------------------------------------------------------
#
# *******
# hd20367
# *******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 --->  0.061+/-0.062
#  1 6032 3.98  0.061 1.32 --->  0.015+/-0.068
#  2 6064 4.30  0.015 1.64 ---> -0.027+/-0.059
#  3 6096 4.62 -0.027 1.32 --->  0.054+/-0.050
#  4 6128 4.30  0.054 1.00 --->  0.144+/-0.058
#  5 6096 4.62  0.144 1.32 --->  0.065+/-0.060
#  6 6128 4.30  0.065 1.00 --->  0.144+/-0.058
# -- Converged at iteration 6 of 50
#  7 6112 4.46  0.144 1.16 --->  0.108+/-0.041
#  8 6128 4.30  0.108 1.32 --->  0.076+/-0.038
#  9 6144 4.46  0.076 1.48 --->  0.058+/-0.038
# 10 6160 4.62  0.058 1.32 --->  0.094+/-0.037
# 11 6176 4.46  0.094 1.16 --->  0.140+/-0.036
# 12 6160 4.62  0.140 1.32 --->  0.099+/-0.041
# 13 6176 4.46  0.099 1.16 --->  0.140+/-0.036
# -- Converged at iteration 13 of 50
# 14 6168 4.54  0.140 1.24 --->  0.120+/-0.032
# 15 6160 4.46  0.120 1.32 --->  0.100+/-0.030
# 16 6168 4.54  0.100 1.24 --->  0.118+/-0.031
# -- Converged at iteration 16 of 50
# 17 6164 4.50  0.118 1.28 --->  0.112+/-0.030
# 18 6168 4.46  0.112 1.24 --->  0.120+/-0.031
# 19 6164 4.50  0.120 1.28 --->  0.112+/-0.030
# -- Converged at iteration 19 of 50
# 20 6166 4.48  0.112 1.26 --->  0.116+/-0.030
# 21 6164 4.50  0.116 1.28 --->  0.112+/-0.030
# 22 6166 4.48  0.112 1.26 --->  0.116+/-0.030
# -- Converged at iteration 22 of 50
# -- Begin final loop
# 23 6165 4.49  0.116 1.27 --->  0.114+/-0.030
# 24 6164 4.48  0.114 1.28 --->  0.111+/-0.030
# 25 6165 4.47  0.111 1.27 --->  0.113+/-0.030
# 26 6166 4.48  0.113 1.28 --->  0.112+/-0.030
# -- Converged at iteration 26 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.112  0.030 ||  0.112  0.031  87 |  0.110  0.022  18
# ------------------------------------------------------
#
# *******
# hd26923
# *******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 ---> -0.007+/-0.048
#  1 6032 4.62 -0.007 1.32 ---> -0.042+/-0.047
#  2 6064 4.30 -0.042 1.00 --->  0.032+/-0.058
#  3 6032 4.62  0.032 1.32 ---> -0.040+/-0.049
#  4 6064 4.30 -0.040 1.00 --->  0.032+/-0.058
# -- Converged at iteration 4 of 50
#  5 6048 4.46  0.032 1.16 --->  0.000+/-0.033
#  6 6064 4.62  0.000 1.32 ---> -0.022+/-0.041
#  7 6080 4.46 -0.022 1.16 --->  0.016+/-0.037
#  8 6064 4.62  0.016 1.32 ---> -0.022+/-0.042
# -- Converged at iteration 8 of 50
#  9 6072 4.54 -0.022 1.24 ---> -0.005+/-0.033
# 10 6064 4.62 -0.005 1.16 --->  0.005+/-0.038
# 11 6056 4.54  0.005 1.08 --->  0.017+/-0.035
# 12 6048 4.46  0.017 1.16 ---> -0.000+/-0.034
# 13 6056 4.54  0.000 1.24 ---> -0.012+/-0.033
# 14 6064 4.46 -0.012 1.16 --->  0.007+/-0.035
# -- Converged at iteration 14 of 50
# 15 6060 4.50  0.007 1.20 --->  0.001+/-0.033
# 16 6056 4.54  0.001 1.16 --->  0.002+/-0.033
# 17 6052 4.50  0.002 1.12 --->  0.011+/-0.033
# 18 6048 4.46  0.011 1.16 ---> -0.001+/-0.033
# 19 6052 4.50 -0.001 1.20 ---> -0.004+/-0.032
# 20 6056 4.54 -0.004 1.16 --->  0.002+/-0.033
# -- Converged at iteration 20 of 50
# 21 6054 4.52  0.002 1.14 --->  0.006+/-0.033
# 22 6052 4.50  0.006 1.12 --->  0.009+/-0.033
# 23 6050 4.48  0.009 1.14 --->  0.005+/-0.033
# 24 6048 4.50  0.005 1.16 ---> -0.001+/-0.032
# 25 6046 4.48 -0.001 1.14 --->  0.002+/-0.033
# 26 6044 4.50  0.002 1.16 ---> -0.004+/-0.032
# 27 6046 4.48 -0.004 1.14 --->  0.002+/-0.033
# 28 6044 4.50  0.002 1.16 ---> -0.004+/-0.032
# -- Converged at iteration 28 of 50
# -- Begin final loop
# 29 6045 4.49 -0.004 1.15 --->  0.000+/-0.033
# 30 6044 4.48  0.000 1.16 ---> -0.002+/-0.033
# 31 6045 4.49 -0.002 1.15 --->  0.000+/-0.033
# -- Converged at iteration 31 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.000  0.033 || -0.000  0.032  86 |  0.002  0.038  18
# ------------------------------------------------------
#
# ------------------------------------------------------
# - Date and time: 01-Aug-2017, 20:14:29
# - Time elapsed: 0H 2M 29S
# Done!
# ------------------------------------------------------

# %% [markdown]
# Re-derive spectroscopic parameters, but:
#
# - Use MARCS model atmospheres (save output to different file)
# - Calculate errors
# - Make PDF figures and save them to a 'marcs' folder
# - Change the y-axis scale to +/-0.2 dex from mean

# %%
sp.grid = 'marcs'
sp.errors = True

pp = q2.specpars.PlotPars()
pp.figure_format = 'pdf'
pp.directory = 'marcs'
pp.afe = [-1000, 0.2]

q2.specpars.solve_all(d, sp, 'solution_marcs.csv', reference_star='Sun', PlotPars=pp)
# Out:
# ------------------------------------------------------
# Initializing ...
# - Date and time: 01-Aug-2017, 20:15:39
# - Model atmospheres: marcs
# - Star data: stars.csv
# - Line list: lines.csv
# ------------------------------------------------------
#
# ***
# Sun
# ***
# Reference star. No calculations needed.
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 5777 4.44  0.000 1.00 --->  0.000+/-0.000
# --
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.000  0.000 ||  0.000  0.000   0 |  0.000  0.000   0
# ------------------------------------------------------
#
# ******
# hd4813
# ******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 ---> -0.174+/-0.102
#  1 6032 3.98 -0.174 1.32 ---> -0.219+/-0.060
#  2 6064 4.30 -0.219 1.64 ---> -0.238+/-0.065
#  3 6096 3.98 -0.238 1.32 ---> -0.180+/-0.058
#  4 6128 4.30 -0.180 1.64 ---> -0.199+/-0.051
#  5 6160 3.98 -0.199 1.32 ---> -0.142+/-0.064
#  6 6192 4.30 -0.142 1.64 ---> -0.163+/-0.045
#  7 6224 4.62 -0.163 1.32 ---> -0.092+/-0.049
#  8 6256 4.30 -0.092 1.00 ---> -0.029+/-0.063
#  9 6224 4.62 -0.029 1.32 ---> -0.087+/-0.052
# 10 6256 4.30 -0.087 1.00 ---> -0.029+/-0.063
# -- Converged at iteration 10 of 50
# 11 6240 4.46 -0.029 1.16 ---> -0.056+/-0.043
# 12 6224 4.30 -0.056 1.32 ---> -0.097+/-0.036
# 13 6240 4.46 -0.097 1.48 ---> -0.106+/-0.034
# 14 6256 4.30 -0.106 1.32 ---> -0.082+/-0.040
# 15 6240 4.46 -0.082 1.48 ---> -0.106+/-0.034
# -- Converged at iteration 15 of 50
# 16 6248 4.38 -0.106 1.40 ---> -0.095+/-0.033
# 17 6256 4.46 -0.095 1.48 ---> -0.097+/-0.033
# 18 6264 4.54 -0.097 1.40 ---> -0.079+/-0.033
# 19 6256 4.46 -0.079 1.32 ---> -0.074+/-0.032
# 20 6248 4.38 -0.074 1.40 ---> -0.095+/-0.033
# -- Converged at iteration 20 of 50
# 21 6252 4.42 -0.095 1.44 ---> -0.097+/-0.032
# 22 6256 4.46 -0.097 1.40 ---> -0.086+/-0.031
# 23 6252 4.42 -0.086 1.36 ---> -0.085+/-0.032
# 24 6248 4.46 -0.085 1.40 ---> -0.091+/-0.031
# -- Converged at iteration 24 of 50
# 25 6250 4.44 -0.091 1.38 ---> -0.088+/-0.031
# 26 6248 4.42 -0.088 1.40 ---> -0.093+/-0.032
# 27 6250 4.44 -0.093 1.38 ---> -0.088+/-0.031
# -- Converged at iteration 27 of 50
# -- Begin final loop
# 28 6249 4.43 -0.088 1.39 ---> -0.090+/-0.031
# 29 6250 4.42 -0.090 1.38 ---> -0.089+/-0.032
# 30 6251 4.43 -0.089 1.39 ---> -0.089+/-0.032
# 31 6252 4.44 -0.089 1.38 ---> -0.087+/-0.031
# 32 6251 4.43 -0.087 1.39 ---> -0.089+/-0.031
# 33 6252 4.44 -0.089 1.38 ---> -0.087+/-0.031
# -- Converged at iteration 33 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
# -0.087  0.031 || -0.087  0.032  86 | -0.085  0.030  17
# ------------------------------------------------------
# Solution with formal errors:
# Teff    =   6252 +/-    13
# log g   =  4.440 +/- 0.034
# D[Fe/H] = -0.087 +/- 0.010
# vt      =   1.38 +/-  0.03
# ------------------------------------------------------
#
# ******
# hd9826
# ******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 --->  0.080+/-0.158
#  1 6032 3.98  0.080 1.32 --->  0.031+/-0.112
#  2 6064 3.66  0.031 1.64 ---> -0.036+/-0.112
#  3 6096 3.98 -0.036 1.96 ---> -0.059+/-0.111
#  4 6128 4.30 -0.059 1.64 --->  0.026+/-0.100
#  5 6160 3.98  0.026 1.32 --->  0.108+/-0.103
#  6 6192 4.30  0.108 1.64 --->  0.064+/-0.093
#  7 6224 3.98  0.064 1.32 --->  0.142+/-0.105
#  8 6256 4.30  0.142 1.64 --->  0.097+/-0.087
#  9 6288 3.98  0.097 1.32 --->  0.179+/-0.112
# 10 6320 4.30  0.179 1.64 --->  0.137+/-0.087
# 11 6352 4.62  0.137 1.32 --->  0.223+/-0.099
# 12 6320 4.30  0.223 1.64 --->  0.138+/-0.087
# 13 6352 4.62  0.138 1.32 --->  0.223+/-0.099
# -- Converged at iteration 13 of 50
# 14 6336 4.46  0.223 1.48 --->  0.187+/-0.087
# 15 6320 4.30  0.187 1.64 --->  0.137+/-0.087
# 16 6336 4.46  0.137 1.48 --->  0.184+/-0.087
# -- Converged at iteration 16 of 50
# 17 6328 4.38  0.184 1.56 --->  0.161+/-0.086
# 18 6336 4.46  0.161 1.48 --->  0.184+/-0.087
# 19 6328 4.38  0.184 1.56 --->  0.161+/-0.086
# -- Converged at iteration 19 of 50
# 20 6332 4.42  0.161 1.52 --->  0.172+/-0.086
# 21 6328 4.38  0.172 1.56 --->  0.160+/-0.086
# 22 6332 4.42  0.160 1.52 --->  0.172+/-0.086
# -- Converged at iteration 22 of 50
# 23 6330 4.40  0.172 1.54 --->  0.166+/-0.086
# 24 6328 4.38  0.166 1.52 --->  0.168+/-0.086
# 25 6326 4.36  0.168 1.54 --->  0.162+/-0.086
# 26 6328 4.38  0.162 1.56 --->  0.160+/-0.086
# 27 6326 4.40  0.160 1.54 --->  0.164+/-0.086
# -- Converged at iteration 27 of 50
# -- Begin final loop
# 28 6325 4.39  0.164 1.53 --->  0.165+/-0.086
# 29 6324 4.38  0.165 1.54 --->  0.162+/-0.086
# 30 6325 4.37  0.162 1.55 --->  0.160+/-0.086
# 31 6326 4.38  0.160 1.54 --->  0.163+/-0.086
# 32 6325 4.37  0.163 1.55 --->  0.160+/-0.086
# -- Converged at iteration 32 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.160  0.086 ||  0.160  0.092  84 |  0.157  0.050  18
# ------------------------------------------------------
# Solution with formal errors:
# Teff    =   6325 +/-    42
# log g   =  4.370 +/- 0.095
# D[Fe/H] =  0.160 +/- 0.032
# vt      =   1.55 +/-  0.08
# ------------------------------------------------------
#
# *******
# hd16673
# *******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 ---> -0.110+/-0.123
#  1 6032 3.98 -0.110 1.32 ---> -0.157+/-0.079
#  2 6064 3.66 -0.157 1.64 ---> -0.213+/-0.100
#  3 6096 3.98 -0.213 1.32 ---> -0.119+/-0.073
#  4 6128 4.30 -0.119 1.64 ---> -0.144+/-0.068
#  5 6160 3.98 -0.144 1.32 ---> -0.081+/-0.073
#  6 6192 4.30 -0.081 1.64 ---> -0.108+/-0.057
#  7 6224 3.98 -0.108 1.32 ---> -0.046+/-0.079
#  8 6256 4.30 -0.046 1.64 ---> -0.074+/-0.054
#  9 6288 4.62 -0.074 1.32 --->  0.004+/-0.053
# 10 6320 4.30  0.004 1.64 ---> -0.035+/-0.058
# 11 6352 4.62 -0.035 1.32 --->  0.042+/-0.046
# 12 6320 4.30  0.042 1.64 ---> -0.035+/-0.057
# 13 6352 4.62 -0.035 1.32 --->  0.042+/-0.046
# -- Converged at iteration 13 of 50
# 14 6336 4.46  0.042 1.48 --->  0.008+/-0.043
# 15 6352 4.62  0.008 1.32 --->  0.044+/-0.046
# 16 6336 4.46  0.044 1.48 --->  0.008+/-0.043
# -- Converged at iteration 16 of 50
# 17 6344 4.54  0.008 1.40 --->  0.027+/-0.041
# 18 6336 4.46  0.027 1.48 --->  0.008+/-0.043
# 19 6344 4.54  0.008 1.40 --->  0.027+/-0.041
# -- Converged at iteration 19 of 50
# 20 6340 4.50  0.027 1.44 --->  0.019+/-0.041
# 21 6336 4.54  0.019 1.40 --->  0.023+/-0.041
# 22 6332 4.50  0.023 1.44 --->  0.015+/-0.041
# 23 6336 4.54  0.015 1.40 --->  0.023+/-0.041
# 24 6332 4.50  0.023 1.44 --->  0.015+/-0.041
# -- Converged at iteration 24 of 50
# 25 6334 4.52  0.015 1.42 --->  0.019+/-0.041
# 26 6332 4.50  0.019 1.44 --->  0.015+/-0.041
# 27 6334 4.52  0.015 1.42 --->  0.019+/-0.041
# -- Converged at iteration 27 of 50
# -- Begin final loop
# 28 6333 4.51  0.019 1.43 --->  0.017+/-0.041
# 29 6332 4.52  0.017 1.44 --->  0.014+/-0.041
# 30 6333 4.51  0.014 1.43 --->  0.017+/-0.041
# -- Converged at iteration 30 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.017  0.041 ||  0.017  0.039  86 |  0.016  0.052  18
# ------------------------------------------------------
# Solution with formal errors:
# Teff    =   6333 +/-    21
# log g   =  4.510 +/- 0.036
# D[Fe/H] =  0.017 +/- 0.015
# vt      =   1.43 +/-  0.04
# ------------------------------------------------------
#
# *******
# hd20367
# *******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 --->  0.066+/-0.062
#  1 6032 3.98  0.066 1.32 --->  0.018+/-0.069
#  2 6064 4.30  0.018 1.64 ---> -0.021+/-0.058
#  3 6096 4.62 -0.021 1.32 --->  0.063+/-0.049
#  4 6128 4.30  0.063 1.00 --->  0.149+/-0.058
#  5 6096 4.62  0.149 1.32 --->  0.071+/-0.059
#  6 6128 4.30  0.071 1.00 --->  0.150+/-0.058
# -- Converged at iteration 6 of 50
#  7 6112 4.46  0.150 1.16 --->  0.113+/-0.040
#  8 6128 4.30  0.113 1.32 --->  0.082+/-0.038
#  9 6144 4.46  0.082 1.48 --->  0.065+/-0.038
# 10 6160 4.62  0.065 1.32 --->  0.102+/-0.036
# 11 6144 4.46  0.102 1.16 --->  0.128+/-0.036
# 12 6128 4.30  0.128 1.32 --->  0.083+/-0.038
# -- Converged at iteration 12 of 50
# 13 6136 4.38  0.083 1.40 --->  0.072+/-0.035
# 14 6144 4.46  0.072 1.32 --->  0.095+/-0.030
# 15 6152 4.54  0.095 1.24 --->  0.116+/-0.032
# 16 6144 4.46  0.116 1.32 --->  0.097+/-0.030
# 17 6152 4.38  0.097 1.24 --->  0.114+/-0.035
# -- Converged at iteration 17 of 50
# 18 6156 4.42  0.114 1.28 --->  0.110+/-0.032
# 19 6160 4.46  0.110 1.32 --->  0.105+/-0.030
# 20 6164 4.50  0.105 1.28 --->  0.117+/-0.029
# 21 6160 4.46  0.117 1.24 --->  0.122+/-0.031
# 22 6164 4.50  0.122 1.28 --->  0.118+/-0.029
# -- Converged at iteration 22 of 50
# 23 6162 4.48  0.118 1.26 --->  0.120+/-0.030
# 24 6160 4.46  0.120 1.28 --->  0.114+/-0.030
# 25 6162 4.48  0.114 1.30 --->  0.111+/-0.030
# 26 6164 4.50  0.111 1.28 --->  0.117+/-0.029
# -- Converged at iteration 26 of 50
# -- Begin final loop
# 27 6163 4.49  0.117 1.27 --->  0.118+/-0.030
# 28 6162 4.48  0.118 1.28 --->  0.116+/-0.030
# 29 6163 4.49  0.116 1.29 --->  0.114+/-0.029
# 30 6164 4.48  0.114 1.28 --->  0.116+/-0.030
# -- Converged at iteration 30 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.116  0.030 ||  0.117  0.031  87 |  0.114  0.023  18
# ------------------------------------------------------
# Solution with formal errors:
# Teff    =   6164 +/-    10
# log g   =  4.480 +/- 0.031
# D[Fe/H] =  0.116 +/- 0.009
# vt      =   1.28 +/-  0.03
# ------------------------------------------------------
#
# *******
# hd26923
# *******
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6000 4.30  0.000 1.00 ---> -0.001+/-0.048
#  1 6032 4.62 -0.001 1.32 ---> -0.036+/-0.046
#  2 6064 4.30 -0.036 1.00 --->  0.039+/-0.059
#  3 6032 4.62  0.039 1.32 ---> -0.034+/-0.049
#  4 6064 4.30 -0.034 1.00 --->  0.039+/-0.058
# -- Converged at iteration 4 of 50
#  5 6048 4.46  0.039 1.16 --->  0.005+/-0.033
#  6 6064 4.62  0.005 1.32 ---> -0.016+/-0.041
#  7 6080 4.46 -0.016 1.16 --->  0.022+/-0.038
#  8 6064 4.62  0.022 1.32 ---> -0.015+/-0.041
# -- Converged at iteration 8 of 50
#  9 6072 4.54 -0.015 1.24 --->  0.003+/-0.033
# 10 6064 4.62  0.003 1.16 --->  0.012+/-0.037
# 11 6056 4.54  0.012 1.08 --->  0.024+/-0.035
# 12 6048 4.46  0.024 1.16 --->  0.004+/-0.033
# 13 6056 4.54  0.004 1.24 ---> -0.006+/-0.033
# 14 6064 4.46 -0.006 1.16 --->  0.013+/-0.035
# -- Converged at iteration 14 of 50
# 15 6060 4.50  0.013 1.20 --->  0.006+/-0.033
# 16 6056 4.54  0.006 1.16 --->  0.009+/-0.032
# 17 6052 4.50  0.009 1.12 --->  0.015+/-0.033
# 18 6048 4.46  0.015 1.16 --->  0.004+/-0.033
# 19 6052 4.50  0.004 1.20 --->  0.000+/-0.032
# 20 6056 4.54  0.000 1.16 --->  0.009+/-0.032
# -- Converged at iteration 20 of 50
# 21 6054 4.52  0.009 1.14 --->  0.012+/-0.032
# 22 6052 4.50  0.012 1.16 --->  0.008+/-0.032
# 23 6050 4.52  0.008 1.14 --->  0.010+/-0.032
# 24 6048 4.50  0.010 1.12 --->  0.013+/-0.033
# 25 6046 4.48  0.013 1.14 --->  0.007+/-0.033
# 26 6044 4.50  0.007 1.16 --->  0.003+/-0.032
# 27 6046 4.48  0.003 1.14 --->  0.007+/-0.033
# 28 6044 4.50  0.007 1.16 --->  0.003+/-0.032
# -- Converged at iteration 28 of 50
# -- Begin final loop
# 29 6045 4.49  0.003 1.15 --->  0.005+/-0.033
# 30 6044 4.50  0.005 1.16 --->  0.003+/-0.032
# 31 6045 4.49  0.003 1.15 --->  0.005+/-0.033
# -- Converged at iteration 31 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.005  0.033 ||  0.005  0.032  86 |  0.004  0.038  18
# ------------------------------------------------------
# Solution with formal errors:
# Teff    =   6045 +/-    12
# log g   =  4.490 +/- 0.028
# D[Fe/H] =  0.005 +/- 0.011
# vt      =   1.15 +/-  0.03
# ------------------------------------------------------
#
# ------------------------------------------------------
# - Date and time: 01-Aug-2017, 20:18:35
# - Time elapsed: 0H 2M 55S
# Done!
# ------------------------------------------------------
