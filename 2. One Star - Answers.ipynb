# %% [markdown]
# ## The Problem: What's up with HD 9826?
#
# Import q2 and load the data, but use solution.csv instead of stars.csv.

# %%
import q2
d = q2.Data('solution.csv', 'lines.csv')

# %% [markdown]
# - Create star objects using q2.Star for hd9826 (object "s") and the Sun (object "r").
# - Use the **get_data_from** method to update the star objects
# - Use the **get_model_atmosphere** method to attach models to the objects

# %%
s = q2.Star('hd9826')
s.get_data_from(d)
s.get_model_atmosphere()

r = q2.Star('Sun')
r.get_data_from(d)
r.get_model_atmosphere()

# %% [markdown]
# Use **q2.specpars.iron_stats** to measure the FeI and FeII abundances of hd9826 ("s") relative to the Sun ("r").

# %%
q2.specpars.iron_stats(s, r)

# %% [markdown]
# Use **q2.specpars.fancy_ironstats_plot** to inspect the classic MOOG-y plots.

# %%
q2.specpars.fancy_ironstats_plot(s)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3b9952bc-1297-4f6f-9a1a-723acd536e75">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="58dbf24f-282e-4fca-bf2f-83e4d96a1309"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("58dbf24f-282e-4fca-bf2f-83e4d96a1309");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("58dbf24f-282e-4fca-bf2f-83e4d96a1309");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '58dbf24f-282e-4fca-bf2f-83e4d96a1309' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7c30a445-fb20-499e-b2a9-340cd7f61508":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"e108f023-de94-41d9-a366-4b429386e154","subtype":"Figure","type":"Plot"},"ticker":{"id":"4626d9a0-7384-477c-b37b-919679c1097d","type":"BasicTicker"}},"id":"4a609aa5-c6dd-4335-b742-1dc4380af75d","type":"Grid"},{"attributes":{"plot":{"id":"e108f023-de94-41d9-a366-4b429386e154","subtype":"Figure","type":"Plot"}},"id":"6290eafa-3ded-40b0-9d1a-12d0363d7cf3","type":"PanTool"},{"attributes":{"plot":{"id":"e108f023-de94-41d9-a366-4b429386e154","subtype":"Figure","type":"Plot"}},"id":"792722e2-5800-4890-a0ac-6b4e75b65819","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"3ea05de4-35a5-4bc9-9e79-aa46a169e94f","type":"ColumnDataSource"},"glyph":{"id":"61885ff9-7633-4803-9f7b-ea44d2a13477","type":"Cross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9791dbf4-420d-41d5-9ab6-a87e261c156c","type":"Cross"},"selection_glyph":null},"id":"0eaaeb11-0c37-4512-b487-a9dbe315cf0a","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"aafeb1ce-ee2c-496d-a4e2-2e43585c5ad1","type":"BoxAnnotation"},"plot":{"id":"e108f023-de94-41d9-a366-4b429386e154","subtype":"Figure","type":"Plot"}},"id":"b3736b71-b80f-4453-b35d-2e5bb8c40d9a","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"size":{"units":"screen","value":11},"x":{"field":"ep"},"y":{"field":"ab"}},"id":"9791dbf4-420d-41d5-9ab6-a87e261c156c","type":"Cross"},{"attributes":{"plot":{"id":"e108f023-de94-41d9-a366-4b429386e154","subtype":"Figure","type":"Plot"}},"id":"8ed086d7-4168-4436-acf5-ace24943c774","type":"ResetTool"},{"attributes":{},"id":"b3038779-d421-4e63-adec-344a4e9817fa","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"e108f023-de94-41d9-a366-4b429386e154","subtype":"Figure","type":"Plot"},"tooltips":[["Wavelength, EP","@ws A, @ep eV"],["EW, REW","@ew mA, @rew"],["Abundance","@abst"]]},"id":"57aff76f-fe53-4194-9f36-9d3c9a854737","type":"HoverTool"},{"attributes":{},"id":"faa55e45-c2c1-485f-9e68-2bbf841b7881","type":"BasicTickFormatter"},{"attributes":{"fill_color":{
a-a55a-b39a62b86919","type":"Grid"},{"id":"c4f8eac9-461a-44c3-8f3c-ecf5145b4c18","type":"LinearAxis"},{"id":"aad032b8-5080-4db8-9307-d3db8de7c69c","type":"Grid"},{"id":"510a68bd-51c4-4ecf-8e7a-d5cbee2cc42b","type":"BoxAnnotation"},{"id":"e56c7275-7a61-486f-9d8a-05f052677729","type":"GlyphRenderer"},{"id":"967ed473-b7ae-4988-b097-29099f36642c","type":"GlyphRenderer"}],"title":{"id":"cd4ae4c7-b284-4429-b1fb-b4f7cf65133d","type":"Title"},"tool_events":{"id":"055f52cc-1c3b-4aab-84bb-7eaa08a6843a","type":"ToolEvents"},"toolbar":{"id":"c7bad48b-c772-4ae1-842c-b0efd5aca3dc","type":"Toolbar"},"x_range":{"id":"907fa9bd-f2fb-415b-924c-ac17f22827aa","type":"DataRange1d"},"y_range":{"id":"3a7fe74c-8bf0-4df6-a3aa-addff605baa9","type":"DataRange1d"}},"id":"0e2bfde1-c3cd-46e0-99fb-49d401a2e664","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"cd4ae4c7-b284-4429-b1fb-b4f7cf65133d","type":"Title"},{"attributes":{},"id":"df258b76-93d4-483d-afef-078eedc5647b","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"field":"colors"},"line_color":{"field":"colors"},"size":{"units":"screen","value":11},"x":{"field":"rew"},"y":{"field":"ab"}},"id":"e227ec49-3f06-4b67-a8cc-3e3cec55b5ab","type":"Circle"},{"attributes":{},"id":"055f52cc-1c3b-4aab-84bb-7eaa08a6843a","type":"ToolEvents"},{"attributes":{"plot":{"id":"0e2bfde1-c3cd-46e0-99fb-49d401a2e664","subtype":"Figure","type":"Plot"},"ticker":{"id":"4f38abc5-acf9-4896-94fb-472160523ab0","type":"BasicTicker"}},"id":"d400c23b-2bac-4d4a-a55a-b39a62b86919","type":"Grid"},{"attributes":{},"id":"4f38abc5-acf9-4896-94fb-472160523ab0","type":"Basi ...

# %% [markdown]
# - Remove the problem line from the star object\*
# - Re-run iron_stats but set silent=False to print main result
#
# \**In practice, I actually just delete/modify the line from the csv file and re-run the whole thing*

# %%
s.linelist['ew'][0] = None
q2.specpars.iron_stats(s, r, silent=False)
# Out:
# FeI  :  0.166 +/- 0.042 (n= 83)
# FeII :  0.155 +/- 0.050 (n= 18)

# %% [markdown]
# Use **q2.specpars.solve_one** to determine new/improved parameters for the star.

# %%
sp = q2.specpars.SolvePars()
q2.specpars.solve_one(s, sp, r)
# Out:
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6329 4.37  0.157 1.53 --->  0.164+/-0.043
#  1 6297 4.69  0.164 1.21 --->  0.213+/-0.087
#  2 6265 4.37  0.213 1.53 --->  0.127+/-0.042
#  3 6233 4.05  0.127 1.21 --->  0.174+/-0.065
#  4 6201 4.37  0.174 1.53 --->  0.095+/-0.052
#  5 6233 4.05  0.095 1.21 --->  0.174+/-0.065
#  6 6201 4.37  0.174 1.53 --->  0.095+/-0.052
# -- Converged at iteration 6 of 50
#  7 6217 4.21  0.095 1.37 --->  0.131+/-0.044
#  8 6201 4.05  0.131 1.53 --->  0.086+/-0.044
#  9 6217 4.21  0.086 1.69 --->  0.065+/-0.046
# 10 6233 4.37  0.065 1.53 --->  0.110+/-0.045
# -- Converged at iteration 10 of 50
# 11 6225 4.29  0.110 1.45 --->  0.120+/-0.042
# 12 6217 4.21  0.120 1.53 --->  0.097+/-0.039
# 13 6225 4.13  0.097 1.45 --->  0.116+/-0.041
# 14 6217 4.21  0.116 1.53 --->  0.097+/-0.039
# 15 6225 4.13  0.097 1.45 --->  0.116+/-0.041
# -- Converged at iteration 15 of 50
# 16 6221 4.17  0.116 1.49 --->  0.106+/-0.039
# 17 6217 4.21  0.106 1.53 --->  0.097+/-0.039
# 18 6221 4.17  0.097 1.49 --->  0.106+/-0.039
# -- Converged at iteration 18 of 50
# 19 6219 4.19  0.106 1.51 --->  0.101+/-0.038
# 20 6217 4.17  0.101 1.53 --->  0.096+/-0.039
# 21 6219 4.19  0.096 1.55 --->  0.093+/-0.039
# 22 6221 4.17  0.093 1.53 --->  0.098+/-0.039
# 23 6219 4.19  0.098 1.55 --->  0.093+/-0.039
# -- Converged at iteration 23 of 50
# -- Begin final loop
# 24 6220 4.18  0.093 1.54 --->  0.095+/-0.039
# 25 6221 4.19  0.095 1.53 --->  0.098+/-0.038
# 26 6220 4.18  0.098 1.54 --->  0.095+/-0.039
# -- Converged at iteration 26 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.095  0.039 ||  0.096  0.036  83 |  0.093  0.050  18
# ------------------------------------------------------

# %% [markdown]
# - Set Teff = 6100 K
# - Solve for logg and vt, keep Teff fixed

# %%
s.teff = 6100
sp.step_teff = 0
q2.specpars.solve_one(s, sp, r)
# Out:
# it Teff logg [Fe/H]  vt           [Fe/H]
# -- ---- ---- ------ ----      --------------
#  0 6100 4.18  0.098 1.54 --->  0.095+/-0.039
#  1 6100 4.50  0.095 1.22 --->  0.114+/-0.107
#  2 6100 4.18  0.114 1.54 --->  0.034+/-0.059
#  3 6100 3.86  0.034 1.22 --->  0.099+/-0.069
#  4 6100 3.54  0.099 1.54 --->  0.009+/-0.086
#  5 6100 3.86  0.009 1.86 ---> -0.042+/-0.072
#  6 6100 4.18 -0.042 1.54 --->  0.034+/-0.059
# -- Converged at iteration 6 of 50
#  7 6100 4.02  0.034 1.38 --->  0.066+/-0.050
#  8 6100 3.86  0.066 1.54 --->  0.023+/-0.050
#  9 6100 4.02  0.023 1.70 ---> -0.002+/-0.054
# 10 6100 3.86 -0.002 1.54 --->  0.023+/-0.050
# -- Converged at iteration 10 of 50
# 11 6100 3.94  0.023 1.62 --->  0.011+/-0.050
# 12 6100 4.02  0.011 1.54 --->  0.031+/-0.046
# 13 6100 3.94  0.031 1.62 --->  0.011+/-0.050
# -- Converged at iteration 13 of 50
# 14 6100 3.98  0.011 1.58 --->  0.022+/-0.047
# 15 6100 3.94  0.022 1.54 --->  0.028+/-0.047
# 16 6100 3.98  0.028 1.58 --->  0.022+/-0.047
# -- Converged at iteration 16 of 50
# 17 6100 3.96  0.022 1.56 --->  0.025+/-0.047
# 18 6100 3.98  0.025 1.58 --->  0.022+/-0.047
# 19 6100 3.96  0.022 1.56 --->  0.025+/-0.047
# -- Converged at iteration 19 of 50
# -- Begin final loop
# 20 6100 3.97  0.025 1.57 --->  0.024+/-0.047
# 21 6100 3.98  0.024 1.56 --->  0.027+/-0.046
# 22 6100 3.97  0.027 1.57 --->  0.024+/-0.047
# -- Converged at iteration 22 of 50
# ------------------------------------------------------
#    D[Fe/H]    ||    D[Fe/H] Fe I   |   D[Fe/H] Fe II
#  0.024  0.047 ||  0.024  0.046  83 |  0.023  0.051  18
# ------------------------------------------------------
